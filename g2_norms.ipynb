# %%
#G2 graphs norm "G2 - offset (baseline)" for lap 3% - old and new - fit CNPEM

import pandas as pd
import matplotlib.pyplot as plt

fit_results_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B2'
]
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (fit_file, raw_file, title) in enumerate(zip(fit_results_files, raw_data_files, titles)):
    fit_results = pd.read_csv(fit_file, sep=",", header=None, skiprows=1)
    raw_data = pd.read_csv(raw_file, sep=",")
    
    time = raw_data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = raw_data[q_col]

        #retrieve the baseline for the current q curve
        baseline = fit_results.iloc[i, 1]  #column 1 (index 1) contains the baseline values
        print(f"Processing {q_col} for {title}: Baseline = {baseline}")

        normalized_intensity = intensity - baseline

        ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("$G_{2} - A$")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Baseline = 1.0518664708342442
# Processing q2 for Laponite 3% w/w - Old Batch: Baseline = 1.0391586670007784
# Processing q3 for Laponite 3% w/w - Old Batch: Baseline = 1.0165307006957454
# Processing q4 for Laponite 3% w/w - Old Batch: Baseline = 1.001741486122208
# Processing q5 for Laponite 3% w/w - Old Batch: Baseline = 1.0324198603634431
# Processing q6 for Laponite 3% w/w - Old Batch: Baseline = 1.0195350929571094
# Processing q7 for Laponite 3% w/w - Old Batch: Baseline = 0.9729523595155392
# Processing q8 for Laponite 3% w/w - Old Batch: Baseline = 0.9592577014541784
# Processing q9 for Laponite 3% w/w - Old Batch: Baseline = 0.9842090596102792
# Processing q10 for Laponite 3% w/w - Old Batch: Baseline = 0.9599975882001492
# Processing q11 for Laponite 3% w/w - Old Batch: Baseline = 0.9843605884348556
# Processing q12 for Laponite 3% w/w - Old Batch: Baseline = 0.972603114336879
# ...

# %%
#G2 graphs norm "G2 - offset (gamma)" for lap 3% - old and new - fit CNPEM

import pandas as pd
import matplotlib.pyplot as plt

fit_results_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B2'
]
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (fit_file, raw_file, title) in enumerate(zip(fit_results_files, raw_data_files, titles)):

    fit_results = pd.read_csv(fit_file, sep=",", header=None, skiprows=1)
    raw_data = pd.read_csv(raw_file, sep=",")
    
    time = raw_data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = raw_data[q_col]

        #retrieve the baseline for the current q curve
        gamma = fit_results.iloc[i, 5]  #column 1 (index 1) contains the baseline values
        print(f"Processing {q_col} for {title}: Gamma = {gamma}")

        normalized_intensity = intensity - gamma

        ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("$G_{2} - A$")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Gamma = 1.0059653382422766
# Processing q2 for Laponite 3% w/w - Old Batch: Gamma = 1.007743198730807
# Processing q3 for Laponite 3% w/w - Old Batch: Gamma = 1.006101779969379
# Processing q4 for Laponite 3% w/w - Old Batch: Gamma = 1.007690190072486
# Processing q5 for Laponite 3% w/w - Old Batch: Gamma = 1.011538735961647
# Processing q6 for Laponite 3% w/w - Old Batch: Gamma = 1.0125075881890369
# Processing q7 for Laponite 3% w/w - Old Batch: Gamma = 1.0103381244743936
# Processing q8 for Laponite 3% w/w - Old Batch: Gamma = 1.0105287699624244
# Processing q9 for Laponite 3% w/w - Old Batch: Gamma = 1.010265441640604
# Processing q10 for Laponite 3% w/w - Old Batch: Gamma = 1.0116362690679035
# Processing q11 for Laponite 3% w/w - Old Batch: Gamma = 1.0111902112141136
# Processing q12 for Laponite 3% w/w - Old Batch: Gamma = 1.0122273583471586
# Processing q13 for Laponite 3% w/w - Old Batch: Gamma = 1.0119718043207504
# ...

# %%
#G2 graphs norm "G2 - offset" for lap 3% - old and new - fit free kww

import pandas as pd
import matplotlib.pyplot as plt

fit_results_file = "kww_fit_results_lap3_free.csv"
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fit_results = pd.read_csv(fit_results_file)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (raw_file, title) in enumerate(zip(raw_data_files, titles)):
    data = pd.read_csv(raw_file, sep=",")
    time = data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = data[q_col]

        #retrieve the offset y0 for the current q_col and file
        fit_row = fit_results[(fit_results['q'] == q_col) & (fit_results['File'] == title)]
        if not fit_row.empty and fit_row['Offset'].iloc[0] is not None:
            y0 = fit_row['Offset'].iloc[0]

            print(f"Processing {q_col} for {title}: Offset = {y0}")

            normalized_intensity = intensity - y0

            ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])
        else:
            print(f"No valid fit for {q_col} in {title}")

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("$G_{2} - A$")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Offset = 1.0057706789209988
# Processing q2 for Laponite 3% w/w - Old Batch: Offset = 1.0076968668514996
# Processing q3 for Laponite 3% w/w - Old Batch: Offset = 1.0060359092671156
# Processing q4 for Laponite 3% w/w - Old Batch: Offset = 1.0075457336489575
# Processing q5 for Laponite 3% w/w - Old Batch: Offset = 1.011474972374242
# Processing q6 for Laponite 3% w/w - Old Batch: Offset = 1.012303586832573
# Processing q7 for Laponite 3% w/w - Old Batch: Offset = 1.0100994331281137
# Processing q8 for Laponite 3% w/w - Old Batch: Offset = 1.0102026137737667
# Processing q9 for Laponite 3% w/w - Old Batch: Offset = 1.0101219944693145
# Processing q10 for Laponite 3% w/w - Old Batch: Offset = 1.0113010603026564
# Processing q11 for Laponite 3% w/w - Old Batch: Offset = 1.0110863245004096
# Processing q12 for Laponite 3% w/w - Old Batch: Offset = 1.0119715745340596
# ...

# %%
#G2 graphs norm "(G2 - offset (baseline))/beta" for lap 3% - old and new - fit CNPEM


import pandas as pd
import matplotlib.pyplot as plt

fit_results_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B2'
]
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (fit_file, raw_file, title) in enumerate(zip(fit_results_files, raw_data_files, titles)):
    fit_results = pd.read_csv(fit_file, sep=",", header=None, skiprows=1)
    raw_data = pd.read_csv(raw_file, sep=",")
    
    time = raw_data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = raw_data[q_col]

        #retrieve the baseline for the current q curve
        baseline = fit_results.iloc[i, 1]  #column 1 (index 1) contains the baseline values
        beta = fit_results.iloc[i, 3] 

        print(f"Processing {q_col} for {title}: Baseline = {baseline}, Beta = {beta}")

        normalized_intensity = (intensity - baseline)/beta

        ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("$G_{2} - A$/β")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Baseline = 1.0518664708342442, Beta = 0.0187450501913036
# Processing q2 for Laponite 3% w/w - Old Batch: Baseline = 1.0391586670007784, Beta = 0.0195943608028588
# Processing q3 for Laponite 3% w/w - Old Batch: Baseline = 1.0165307006957454, Beta = 0.0194728781208054
# Processing q4 for Laponite 3% w/w - Old Batch: Baseline = 1.001741486122208, Beta = 0.018835114082088
# Processing q5 for Laponite 3% w/w - Old Batch: Baseline = 1.0324198603634431, Beta = 0.0189062817749017
# Processing q6 for Laponite 3% w/w - Old Batch: Baseline = 1.0195350929571094, Beta = 0.0176787543665981
# Processing q7 for Laponite 3% w/w - Old Batch: Baseline = 0.9729523595155392, Beta = 0.0178299903192396
# Processing q8 for Laponite 3% w/w - Old Batch: Baseline = 0.9592577014541784, Beta = 0.0177475331615985
# Processing q9 for Laponite 3% w/w - Old Batch: Baseline = 0.9842090596102792, Beta = 0.0183075151647914
# ...

# %%
#G2 graphs norm "(G2 - offset (gamma))/beta" for lap 3% - old and new - fit CNPEM

import pandas as pd
import matplotlib.pyplot as plt

fit_results_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_fitting_data\Auto-correlation fitting results lap3 B2'
]
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (fit_file, raw_file, title) in enumerate(zip(fit_results_files, raw_data_files, titles)):

    fit_results = pd.read_csv(fit_file, sep=",", header=None, skiprows=1)
    raw_data = pd.read_csv(raw_file, sep=",")
    
    time = raw_data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = raw_data[q_col]

        #retrieve the baseline for the current q curve
        gamma = fit_results.iloc[i, 5]  #column 1 (index 1) contains the baseline values
        beta = fit_results.iloc[i, 3] 

        print(f"Processing {q_col} for {title}: Gamma = {gamma}, Beta = {beta}")

        normalized_intensity = (intensity - gamma)/beta

        ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("$G_{2} - A$/β")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Gamma = 1.0059653382422766, Beta = 0.0187450501913036
# Processing q2 for Laponite 3% w/w - Old Batch: Gamma = 1.007743198730807, Beta = 0.0195943608028588
# Processing q3 for Laponite 3% w/w - Old Batch: Gamma = 1.006101779969379, Beta = 0.0194728781208054
# Processing q4 for Laponite 3% w/w - Old Batch: Gamma = 1.007690190072486, Beta = 0.018835114082088
# Processing q5 for Laponite 3% w/w - Old Batch: Gamma = 1.011538735961647, Beta = 0.0189062817749017
# Processing q6 for Laponite 3% w/w - Old Batch: Gamma = 1.0125075881890369, Beta = 0.0176787543665981
# Processing q7 for Laponite 3% w/w - Old Batch: Gamma = 1.0103381244743936, Beta = 0.0178299903192396
# Processing q8 for Laponite 3% w/w - Old Batch: Gamma = 1.0105287699624244, Beta = 0.0177475331615985
# Processing q9 for Laponite 3% w/w - Old Batch: Gamma = 1.010265441640604, Beta = 0.0183075151647914
# ...

# %%
#G2 graphs norm "(G2 - offset)/beta" for lap 3% - old and new - fit free kww

import pandas as pd
import matplotlib.pyplot as plt

fit_results_file = "kww_fit_results_lap3_free.csv"
raw_data_files = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]
titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

fit_results = pd.read_csv(fit_results_file)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for idx, (raw_file, title) in enumerate(zip(raw_data_files, titles)):
    data = pd.read_csv(raw_file, sep=",")
    time = data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    ax = axes[idx]

    for i, q_col in enumerate(q_columns):
        intensity = data[q_col]

        #retrieve the offset y0 for the current q_col and file
        fit_row = fit_results[(fit_results['q'] == q_col) & (fit_results['File'] == title)]
        if not fit_row.empty and fit_row['Offset'].iloc[0] is not None:
            y0 = fit_row['Offset'].iloc[0]
            beta = fit_row['B'].iloc[0]

            print(f"Processing {q_col} for {title}: Offset = {y0}, Beta = {beta}")

            normalized_intensity = (intensity - y0)/beta

            ax.scatter(time, normalized_intensity, label=f'{q_col}', marker=markers[i % len(markers)])
        else:
            print(f"No valid fit for {q_col} in {title}")

    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')
    ax.set_xlim(0.5, 3000)
    ax.set_ylabel("($G_{2}$ - A)/β")
    ax.set_title(f"Normalized {title}")
    ax.grid(True)

fig.legend(loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Processing q1 for Laponite 3% w/w - Old Batch: Offset = 1.0057706789209988, beta = 0.0185644881761937
# Processing q2 for Laponite 3% w/w - Old Batch: Offset = 1.0076968668514996, beta = 0.0191937194447433
# Processing q3 for Laponite 3% w/w - Old Batch: Offset = 1.0060359092671156, beta = 0.0193907800012
# Processing q4 for Laponite 3% w/w - Old Batch: Offset = 1.0075457336489575, beta = 0.0190666372060106
# Processing q5 for Laponite 3% w/w - Old Batch: Offset = 1.011474972374242, beta = 0.018508655501447
# Processing q6 for Laponite 3% w/w - Old Batch: Offset = 1.012303586832573, beta = 0.0177991295245106
# Processing q7 for Laponite 3% w/w - Old Batch: Offset = 1.0100994331281137, beta = 0.018851880654255
# Processing q8 for Laponite 3% w/w - Old Batch: Offset = 1.0102026137737667, beta = 0.0192122818475775
# Processing q9 for Laponite 3% w/w - Old Batch: Offset = 1.0101219944693145, beta = 0.0190143151205174
# ...
