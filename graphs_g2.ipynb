# %%
#G2 graphs for lap 3% - old and new


import pandas as pd 
import matplotlib.pyplot as plt

file_names = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B1\Auto-correlation lap3 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_B2\Auto-correlation lap3 B2',
]

titles = [
    "Laponite 3% w/w - Old Batch",
    "Laponite 3% w/w - New Batch"
]

markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

#conf of subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

handles, labels = [], [] #stores the markers and respective labels for the legend 

for idx, (file_name, title) in enumerate(zip(file_names, titles)): #adds an index to each pair from zip and the divmod distributes it to the following row and column
    data = pd.read_csv(file_name, sep=",")
    time = data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    row, col = divmod(idx, 2)  #divmod returns the quotient and remainder of the division of idx/2
    ax = axes[col]
    for i, q_col in enumerate(q_columns):
        scatter = ax.scatter(time, data[q_col], label=q_col, marker=markers[i % len(markers)])
        if idx == 0:  #collects legend information only from the first subplot
            handles.append(scatter)
            labels.append(q_col)
    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')  
    ax.set_xlim(0.5, 3000)  
    if col == 0:  
        ax.set_ylabel("$G_{2}$ ($nm^{-1}$)") #puts one legend for each row 
    ax.set_title(title)
    ax.grid(True)

fig.legend(handles, labels, loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()

# %%
#G2 graphs for lap 3% + oils - old

import pandas as pd
import matplotlib.pyplot as plt

file_names = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3L01 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3L04 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3R01 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3R04 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3T01 B1',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B1\Auto-correlation L3T04 B1'
]

titles = [
    "Laponite 3% w/w + Lavender Oil 0.1 M - Old Batch",
    "Laponite 3% w/w + Lavender Oil 0.4 M - Old Batch",
    "Laponite 3% w/w + Rosemary Oil 0.1 M - Old Batch",
    "Laponite 3% w/w + Rosemary Oil 0.4 M - Old Batch",
    "Laponite 3% w/w + Tea Tree Oil 0.1 M - Old Batch",
    "Laponite 3% w/w + Tea Tree Oil 0.4 M - Old Batch"
]


markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

#conf of subplots
fig, axes = plt.subplots(3, 2, figsize=(14, 15))

handles, labels = [], [] #stores the markers and respective labels for the legend 

for idx, (file_name, title) in enumerate(zip(file_names, titles)): #adds an index to each pair from zip and the divmod distributes it to the following row and column
    data = pd.read_csv(file_name, sep=",")
    time = data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    row, col = divmod(idx, 2)  #divmod returns the quotient and remainder of the division of idx/2
    ax = axes[row, col]
    for i, q_col in enumerate(q_columns):
        scatter = ax.scatter(time, data[q_col], label=q_col, marker=markers[i % len(markers)])
        if idx == 0:  #collects legend information only from the first subplot
            handles.append(scatter)
            labels.append(q_col)
    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')  
    ax.set_xlim(0.5, 3000)  
    if col == 0:  
        ax.set_ylabel("$G_{2}$ ($nm^{-1}$)") #puts one legend for each row 
    ax.set_title(title)
    #ax.legend()
    ax.grid(True)


fig.legend(handles, labels, loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()

# %%
#G2 graphs for lap 3% + oils - new


import pandas as pd
import matplotlib.pyplot as plt

file_names = [
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3L01 B2',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3L04 B2',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3R01 B2',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3R04 B2',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3T01 B2',
    r'C:\Users\adria\Documents\LENS - PIBIC\PIBIC - 2024-2025\analysis\XPCS - Python analysis\XPCS_data\L3_Oils_B2\Auto-correlation L3T04 B2'
]

titles = [
    "Laponite 3% w/w + Lavender Oil 0.1 M - New Batch",
    "Laponite 3% w/w + Lavender Oil 0.4 M - New Batch",
    "Laponite 3% w/w + Rosemary Oil 0.1 M - New Batch",
    "Laponite 3% w/w + Rosemary Oil 0.4 M - New Batch",
    "Laponite 3% w/w + Tea Tree Oil 0.1 M - New Batch",
    "Laponite 3% w/w + Tea Tree Oil 0.4 M - New Batch"
]


markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', '+', 'x', 'd', '1', '4']

#conf of subplots
fig, axes = plt.subplots(3, 2, figsize=(14, 15))

handles, labels = [], [] #stores the markers and respective labels for the legend 

for idx, (file_name, title) in enumerate(zip(file_names, titles)): #adds an index to each pair from zip and the divmod distributes it to the following row and column
    data = pd.read_csv(file_name, sep=",")
    time = data['time']
    q_columns = [f'q{i}' for i in range(1, 16)]
    row, col = divmod(idx, 2)  #divmod returns the quotient and remainder of the division of idx/2
    ax = axes[row, col]
    for i, q_col in enumerate(q_columns):
        scatter = ax.scatter(time, data[q_col], label=q_col, marker=markers[i % len(markers)])
        if idx == 0:  #collects legend information only from the first subplot
            handles.append(scatter)
            labels.append(q_col)
    ax.set_xlabel("Time (s)")
    ax.set_xscale('log')  
    ax.set_xlim(0.5, 3000) 
    if col == 0:  
        ax.set_ylabel("$G_{2}$ ($nm^{-1}$)") #puts one legend for each row 
    ax.set_title(title)
    #ax.legend()
    ax.grid(True)


fig.legend(handles, labels, loc='center right', title="q labels", bbox_to_anchor=(1.09, 0.5))
plt.tight_layout()
plt.show()
